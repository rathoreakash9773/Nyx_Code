# %%
import os
import csv
import urllib.parse
import re
import requests
import logging
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor
import time

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def download_image(image_data):
    image_url, output_dir, title = image_data
    try:
        start_time = time.time()
        response = requests.get(image_url, timeout=180) #Set a timeout for the request 
        if response.status_code == 200:
            image_content = response.content
            image_name = re.sub(r'[\\/:*?"<>|]', '', title) # Sanitize title for file name
            image_path = os.path.join(output_dir, f"{image_name}.jpg") # Save as JPG

            # Check if the image already exists, skip download if it does
            if not os.path.exists(image_path):
                with open(image_path, 'wb') as f:
                    f.write(image_content)
                    f.flush()
                end_time = time.time()
                logger.info(f"Image downloaded: {image_path}. Time taken: {end_time - start_time} seconds")
                return image_path
            else:
                logger.info(f"Image already exists: {image_path}")
        else:
            logger.error(f"Failed to download image from: {image_url}. Status code: {response.status_code}")
    except Exception as e:
        logger.error(f"Error downloading image from {image_url}: {e}")
    return None

def extract_and_download_images(url_template, output_dir, start_page, end_page):
    output_csv = os.path.join(output_dir, 'images.csv')
    csv_header = ['Title', 'URL']
    unique_urls = set()

    try:
        with open(output_csv, 'w', newline='', encoding='utf-8') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow(csv_header)

            with ThreadPoolExecutor(max_workers=20) as executor:
                for page_number in range(start_page, end_page + 1):
                    current_url = urllib.parse.urljoin(url_template, f"?search_page={page_number}")
                    response = requests.get(current_url, timeout=180)
                    if response.status_code == 200:
                        html_content = response.content
                        soup = BeautifulSoup(html_content, 'html.parser')
                        img_elements = soup.find_all('img')
                        image_data_list = []
                        for img_element in img_elements:
                            src_image_url = img_element.get('src')
                            if src_image_url and src_image_url.endswith('.jpg') and src_image_url not in unique_urls:
                                title = img_element.get('alt', '')
                                writer.writerow([title, src_image_url])
                                image_data_list.append((src_image_url, output_dir, title))
                                unique_urls.add(src_image_url)
                        image_paths = executor.map(download_image, image_data_list)
                    else:
                        logger.error(f"Failed to fetch content from {current_url}. Status code: {response.status_code}")
    except Exception as e:
        logger.error(f"An error occurred: {e}")

if __name__ == "__main__":
    url_template = "https://www.vecteezy.com/free-photos/nature" # Add website url 
    output_directory = "C:/nyx/vect/downloaded_image3.3" # Add the desired output directory 
    start_page = 1
    end_page = 2 # Modify to the desired last page 

    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    extract_and_download_images(url_template, output_directory, start_page, end_page)

    logger.info("Data download and CSV generation complete.")
# Out:
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Banners.jpg. Time taken: 7.392866849899292 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Textures.jpg. Time taken: 7.45831298828125 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for People.jpg. Time taken: 7.512415885925293 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Animals.jpg. Time taken: 7.50049614906311 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Travel.jpg. Time taken: 7.548670053482056 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Wedding.jpg. Time taken: 7.566527366638184 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Nature.jpg. Time taken: 7.592215299606323 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Lifestyle.jpg. Time taken: 7.584902048110962 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Pattern.jpg. Time taken: 7.635211944580078 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Food & Drink.jpg. Time taken: 7.618996620178223 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Cityscapes.jpg. Time taken: 7.469667196273804 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Plants.jpg. Time taken: 7.659085750579834 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Flowers.jpg. Time taken: 7.689815521240234 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Landscape.jpg. Time taken: 7.675065279006958 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Family.jpg. Time taken: 7.4190521240234375 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Backgrounds.jpg. Time taken: 7.764067888259888 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Business.jpg. Time taken: 7.775929927825928 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Timelapses.jpg. Time taken: 7.514431715011597 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\Category image for Animals.jpg
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\Category image for Travel.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Category image for Aerials.jpg. Time taken: 6.4332966804504395 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Travel to the beautiful Colorful majestic waterfall in national park forest during autumn, soft water of the stream in the natural park photo.jpg. Time taken: 6.471067190170288 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\SVGs.jpg. Time taken: 6.5518739223480225 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\Category image for Backgrounds.jpg
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\Category image for Lifestyle.jpg
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\Category image for Nature.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\PNGs.jpg. Time taken: 6.651801586151123 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Idyllic mountain landscape with fresh green meadows and blooming wildflowers. Idyllic nature countryside view, rural outdoor natural view. idyllic banner nature, panoramic spring summer scenery photo.jpg. Time taken: 6.606827259063721 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Nature landscape of Maroon bell  in Colorado photo.jpg. Time taken: 6.524167060852051 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\PSDs.jpg. Time taken: 6.811316013336182 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Awesome nature landscape. Beautiful scene with high Tatra mountain peaks, stones in mountain lake, calm lake water, reflection, colorful sunset sky. Amazing nature background. Autumn adventure hiking photo.jpg. Time taken: 6.746399641036987 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Sea ocean beach sunset sunrise landscape outdoor. Water wave with white foam. Beautiful sunset colorful sky with clouds. Natural island panoramic background. Idyllic amazing tropical island shore photo.jpg. Time taken: 6.865770101547241 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Air drone aerial view cloudscape landscape nature outdoor fly from above earth clouds sun sunbeams. Graphic Art photo.jpg. Time taken: 6.7330663204193115 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Beautiful landscape in the mountains. Nature background. AI generated photo.jpg. Time taken: 6.780102491378784 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Wonderful scenery, amazing summer landscape of blooming lavender flowers, peaceful sunset view, agriculture scenic. Beautiful nature background, inspirational panorama photo.jpg. Time taken: 6.7012176513671875 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Beautiful early autumn scene of High Tatra lake. Colorful morning view of mountains sunlight, pine forest trees, idyllic sky reflection. Amazing nature landscape. Hiking adventure, beauty outdoors photo.jpg. Time taken: 6.989419937133789 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Stunning vertical garden backgrounds featuring lush plants against a captivating wall backdrop. Perfect for adding a touch of nature to your projects. AI Generated photo.jpg. Time taken: 6.7151947021484375 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\A large meadow in the background is the sky. nature background image concept photo.jpg. Time taken: 6.85417103767395 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Spa natural background. Illustration AI Generative photo.jpg. Time taken: 6.9796764850616455 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Autumn forest road leaves fall in ground landscape on autumnal background. Beautiful seasonal nature landscape, bright sunlight with golden orange tree leaves, idyllic adventure hiking pathway photo.jpg. Time taken: 7.034125566482544 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Amazing island beach. Maldives from aerial view tranquil tropical landscape seaside with palm trees on white sandy beach. Exotic nature shore, luxury resort island. Beautiful summer holiday tourism photo.jpg. Time taken: 5.931321859359741 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Natural coral reef vivid background photo.jpg. Time taken: 6.1273722648620605 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Nature elegance reflected in a lotus pond generated by AI photo.jpg. Time taken: 6.274455308914185 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Orange cartoon anime design nature background, forest and sun at sunset. Landscape illustration generative ai photo.jpg. Time taken: 6.195663213729858 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Environmentally friendly planet. Symbolic tree made from green leaves and branches with sketches map of the world. Minimal nature concept. Think Green. Ecology Concept. Top view. Flat lay. Generate Ai photo.jpg. Time taken: 6.69395899772644 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Upstream view on top of the dam Surrounded by mountains and lush nature photo.jpg. Time taken: 6.443939685821533 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Spring blossom background. Beautiful nature scene with blooming tree and sun flare. Sunny day. Spring flowers. Beautiful Orchard. Abstract blurred background, generative ai photo.jpg. Time taken: 6.935108661651611 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Sea turtle swimming in the under sea , Beautiful Underwater and colorfull coral in wild nature of the Pacific Ocean. Generate Ai photo.jpg. Time taken: 6.915573835372925 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Young plant growing in the morning light and green nature photo.jpg. Time taken: 6.628184080123901 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\natures close up beauty vibrant flowers, defocused background ,generative AI photo.jpg. Time taken: 6.495746612548828 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Nature outdoor landscape wild beauty mountain river field drone air photo illustration. Adventure travel vacation vibe. Graphic Art.jpg. Time taken: 6.59045672416687 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Splendid springtime nature landscape created with generative ai technology photo.jpg. Time taken: 7.264237880706787 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Idyllic mountain panoramic landscape. Fresh green meadows and blooming wildflowers, sun ray. Beautiful nature countryside view, rural sunny outdoor natural. Bright banner nature spring summer panorama photo.jpg. Time taken: 6.833732604980469 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Iceland beautiful landscape, Icelandic nature landscape photo.jpg. Time taken: 7.145116567611694 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Nature beautiful landscape wallpaper background design photo.jpg. Time taken: 7.341897487640381 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Bolivia salt lake. Pink clouds reflect on water lake surface. Adventure travel vacation outdoor nature vibe. Graphic Art photo.jpg. Time taken: 7.276833772659302 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Beautiful view of nature trail in the morning, Grindelwald First, Highest peaks Eiger, Switzerland Alps. For trekking, hiking, mountaineering or nature walk activities. photo.jpg. Time taken: 6.987900495529175 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Photorealistic panoramic view of the beautiful natural river landscape in the forest created with ai generative photo.jpg. Time taken: 7.1523354053497314 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Storm in ocean with lighting natural disaster phenomenon, AI Generated photo.jpg. Time taken: 7.218307733535767 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Romantic beach sunset. Palm tree with swing hanging before majestic clouds sky. Dream nature landscape, tropical island paradise, couple destination. Love coast, closeup sea sand. Relax pristine beach photo.jpg. Time taken: 7.619063377380371 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Landscape Photography of a vibrant summer meadow, a tranquil scene of uncultivated beauty in nature. photo.jpg. Time taken: 6.360000371932983 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Summer seascape beautiful waves, blue sea water in sunny day. Top view from drone. Sea aerial view, amazing tropical nature background. Beautiful bright sea waves splashing and beach sand sunset light photo.jpg. Time taken: 6.45168662071228 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Landscape of beautiful misty waterfall hidden in the deep jungle and river flow shading between the tall tree at the nature. AI Generated photo.jpg. Time taken: 6.467829465866089 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Adventure outdoor nature mist fog clouds forest trees landscape background wild explore. Graphic Art photo.jpg. Time taken: 6.590867519378662 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Spring summer sunset sunrise meadow grass and blurred forest field landscape. Idyllic nature scenic, closeup plants, wild flowers under soft sunlight. Idyllic relax adventure, nature walk or hike photo.jpg. Time taken: 6.528493881225586 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Starry night landscape with mountain and milky way sky background. Beauty in nature and Astrology science concept. Digital art fantasy illustration. Generative AI photo.jpg. Time taken: 6.7214250564575195 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Powerful large natural waterfall flowing from cliff in summer photo.jpg. Time taken: 6.517069578170776 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\Romantic beach sunset. Palm tree with swing hanging before majestic clouds sky. Dream nature landscape, tropical island paradise, couple destination. Love coast, closeup sea sand. Relax pristine beach photo.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Family Vacation In Nature. Young Mom, Dad And Their Daughters And Son Meet At Sunset. Created with generative AI. photo.jpg. Time taken: 6.580202341079712 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Summer travel background. Exotic tropical beach island, paradise coast. Palm trees white sand, amazing sky ocean lagoon. Fantastic beautiful nature background, sunny day idyllic inspirational vacation photo.jpg. Time taken: 6.771923542022705 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Natural park in small city. photo.jpg. Time taken: 6.914443016052246 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Beautiful nature lanscape of Lofoten in Norway photo.jpg. Time taken: 6.90057373046875 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Walk way in the natural park. photo.jpg. Time taken: 7.149936676025391 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Beautiful landscape. Panorama lavender field summer sunset landscape near Valensole. Provence, France. Panoramic view of French lavender field at sunset. Sunset minimalism landscape, peaceful nature photo.jpg. Time taken: 6.750385046005249 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Majestic mountain range reflects tranquil beauty in nature generated by AI photo.jpg. Time taken: 7.050504684448242 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Bolivia salt lake. Pink clouds reflect on water lake surface. Adventure travel vacation outdoor nature vibe. Graphic Art photo.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Scandinavian triangular aframe house hotel apartment. Nature outdoor vacation relax adventures vibe. Graphic Art photo.jpg. Time taken: 7.002992630004883 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Tropical beach background as summer landscape with beach swing or hammock and white sand and calm sea for beach banner. Perfect beach scene vacation and summer holiday concept. Nature landscape photo.jpg. Time taken: 7.058722257614136 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Beautiful nature ocean clouds seascape panorama. Beautiful tropical sea view photo.jpg. Time taken: 7.614216327667236 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Seljalandsfoss waterfall at sunset in Iceland photo.jpg. Time taken: 7.403863430023193 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Beautiful mountain and landscape nature panorama Rondane National Park Norway. photo.jpg. Time taken: 6.356855869293213 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Summer travel background. Exotic tropical beach island, paradise coast. Palm trees white sand, amazing sky ocean lagoon. Fantastic beautiful nature panorama, sunny day idyllic inspirational vacation photo.jpg. Time taken: 6.734803915023804 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Fertile green leaves and trees There is a light shining into the beautiful natural concept. photo.jpg. Time taken: 6.954893112182617 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Wooden bridge pier against a beautiful sky measure used for natural background, background and multi-stage sea photo.jpg. Time taken: 6.358483076095581 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\A Stunning Jungle-Themed Empty Space with Nature Background, Perfect for Professional Product Display photo.jpg. Time taken: 6.232872486114502 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Beatiful nature lake and forest in the morning photo.jpg. Time taken: 6.67587423324585 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Moonlight over the sea at night in full moonlight. Natural background. photo.jpg. Time taken: 6.255203723907471 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Landscape Waterfall Than Bok Khorani. Thanbok Khoranee National Park lake, nature trail, forest, mangrove forest, travel nature, travel Thailand. Nature Study. Attractions. photo.jpg. Time taken: 6.695308685302734 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\Wooden bridge pier against a beautiful sky measure used for natural background, background and multi-stage sea photo.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Natural waterfall wallpaper photo.jpg. Time taken: 6.283234119415283 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Desert canyon mountain rock hill nature adventure landscape travel explore lake tree vacation hiking vibe sunset. Graphic Art photo.jpg. Time taken: 6.059786081314087 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\Beautiful nature lanscape of Lofoten in Norway photo.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Nature outdoor landscape of yacht marine boat ship at dock port harbour. Vacation relax landscape background vibe. Graphic Art photo.jpg. Time taken: 6.28605842590332 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Adventure outdoor nature mist fog clouds forest trees landscape background wild explore. Graphic Art photo.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Professional Photography of an Empty Space Mockup Podium with a Jungle-Themed Nature Background for a Stunning Visual Impact photo.jpg. Time taken: 7.079268455505371 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Sheeps grazing on beautiful mountain hills landscape. Peace chill outdoor nature vibe. Graphic Art photo.jpg. Time taken: 6.302043437957764 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Nature outdoor landscape of yacht marine boat ship at dock port harbour. Vacation relax landscape background vibe. Graphic Art photo.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Landscape natural beautiful mountains and blue sky panorama photo.jpg. Time taken: 6.289520740509033 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Beach nature concept. Palm beach in tropical idyllic paradise island. Exotic landscape for dreamy and inspirational summer scenery use for background or wallpaper photo.jpg. Time taken: 6.524247169494629 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Fog and sunrise on the river photo.jpg. Time taken: 6.694157600402832 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Beautiful morning view indonesia. Panorama Landscape paddy fields with beauty color and sky natural light photo.jpg. Time taken: 6.765138387680054 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\background nature Flower mexican aster. purple flowers. background blur. wallpaper Flower, Space for text. photo.jpg. Time taken: 6.516606092453003 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Photo illustration of wine grape vineyard winery plant field nature outdoor field. Graphic Art.jpg. Time taken: 6.576468229293823 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\evening nature exotic landscape, big tree closeup mountains portrait, with sunset, generative ai photo.jpg. Time taken: 6.60905122756958 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Closeup island coast palm trees sea sand beach. Blurred beautiful tropical beach landscape. Inspire seascape horizon waves splashing. Colorful sunset sky tranquil relax summer seaside, dream nature photo.jpg. Time taken: 6.836302757263184 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Wooden walkway into the lake with natural scenery of sunset and silhouette of forest in background photo.jpg. Time taken: 6.244110584259033 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Desert canyon mountain rock hill nature adventure landscape travel explore lake tree vacation hiking vibe sunset. Graphic Art photo.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\plant growing in hand on green nature with sunlight background. eco environment concept photo.jpg. Time taken: 6.420187950134277 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\Professional Photography of an Empty Space Mockup Podium with a Jungle-Themed Nature Background for a Stunning Visual Impact photo.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Blue Sky abstract panoramic background. Coulds nature concept with copy space. Texture and Pattern wallpaper backgrounds. photo.jpg. Time taken: 7.100738525390625 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\AI Generated. AI Generative. Adventure outdoor nature vacation wild gravel road to the wood house hotel. Countryside farm vibe. Graphic Art photo.jpg. Time taken: 7.069700479507446 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Silhouette of beautiful sunset on the sea beach with palm tree for travel in holiday relax time,  on nature background photo.jpg. Time taken: 6.479485034942627 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Autumn natural background. Illustration AI Generative photo.jpg. Time taken: 6.715718507766724 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Smooth waterfall background photo.jpg. Time taken: 6.717406988143921 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Tranquil lotus pond reflects beauty of nature   generated by AI photo.jpg. Time taken: 6.699796915054321 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Field of daisies in golden rays of the setting sun in spring summer nature with an orange butterfly outdoors, AI Generated photo.jpg. Time taken: 6.765794992446899 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Cute animal on nature. Ai image photo.jpg. Time taken: 6.7799458503723145 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Moss-covered tree in a forest photo.jpg. Time taken: 6.2062766551971436 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Fantastic view of the nature reserve Monte Cofano. Dramatic scen photo.jpg. Time taken: 12.90229606628418 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\Cycling through nature beauty on a tranquil autumn day generated by AI photo.jpg. Time taken: 4.848362684249878 seconds
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\womens day.jpg. Time taken: 4.178762435913086 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\womens day.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\textures.jpg. Time taken: 3.577173948287964 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\textures.jpg
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\womens day.jpg
# INFO:__main__:Image downloaded: C:/nyx/vect/downloaded_image3.3\blue background.jpg. Time taken: 3.55718994140625 seconds
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\textures.jpg
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\blue background.jpg
# INFO:__main__:Image already exists: C:/nyx/vect/downloaded_image3.3\blue background.jpg
# INFO:__main__:Data download and CSV generation complete.
