# %%
#download images
import os
import requests
import csv
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Function to download images from URLs
def download_image(image_url, output_dir, title):
    try:
        response = requests.get(image_url)
        if response.status_code == 200:
            image_content = response.content
            image_name = os.path.basename(image_url)
            image_path = os.path.join(output_dir, image_name)
            with open(image_path, 'wb') as f:
                f.write(image_content)
            print(f"Image downloaded: {image_path}")
        else:
            print(f"Failed to download image from: {image_url}")
    except Exception as e:
        print(f"Error downloading image: {e}")

# Function to extract and download images
def extract_and_download_images(url, output_dir):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            img_elements = soup.find_all('img')
            for img_element in img_elements:
                img_url = img_element.get('src')
                if img_url and img_url.endswith('.jpg'):
                    img_url = urljoin(url, img_url)
                    title = img_element.get('alt', '')
                    download_image(img_url, output_dir, title)
    except Exception as e:
        print(f"An error occurred: {e}")

# Output directory for downloaded images
output_directory = "pikwizard_images"
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# URL of the Pikwizard website
url = "https://pikwizard.com/most-popular/sports-backgrounds-images/"

# Extract and download images
extract_and_download_images(url, output_directory)
# Out:
# Image downloaded: pikwizard_images\42dc903754199f8ccec6a2a571cbf89a.jpg
# Image downloaded: pikwizard_images\896f26132e7fe5b8649259ab0cdf8114.jpg
# Image downloaded: pikwizard_images\568e9e3d8434f7ecb13562e24b7e680a.jpg
# Image downloaded: pikwizard_images\9d0989c264738fee794aa469288f6731.jpg
# Image downloaded: pikwizard_images\11495840d5d724ae10e1e525fa310fff.jpg
# Image downloaded: pikwizard_images\881946ee69edfb1e197ee81c6083a460.jpg
# Image downloaded: pikwizard_images\66d2690058f99fd503dc3f1a3a07ff5f.jpg
# Image downloaded: pikwizard_images\6567d21c791f980c972254110bdc4edf.jpg
# Image downloaded: pikwizard_images\240_F_336411417_DtEpDXNacEM9Ay6Af1DDPq2rODrJa5zd.jpg
# Image downloaded: pikwizard_images\44d62a1163af51d0065fe6cca22d48e7.jpg
# Image downloaded: pikwizard_images\877eff0bb70bf424dad0aba7201b2e36.jpg
# Image downloaded: pikwizard_images\b594eb62c3416aeed8353de2c0b49e18.jpg
# Image downloaded: pikwizard_images\ebf62ac0cbe2779901ab260f2c5bed9b.jpg
# Image downloaded: pikwizard_images\2d9efb68394b337ad1905880e9c2df14.jpg
# Image downloaded: pikwizard_images\240_F_564806691_ywqJYQqDokVeNVUQZaF1RhYyYdUmNUsz.jpg
# Image downloaded: pikwizard_images\810e94072e43b860cabe0ba9210a6db8.jpg
# Image downloaded: pikwizard_images\953791907eac0d0b33706642b6b2dc83.jpg
# Image downloaded: pikwizard_images\912ebf8bebbd8b7dfdb2fe47e119a3d0.jpg
# Image downloaded: pikwizard_images\8e211849a593040e8072da405d40dd3c.jpg
# Image downloaded: pikwizard_images\cee00bbc145c1aafe056591a54b37956.jpg
# Image downloaded: pikwizard_images\288890eb678f9bc310956a1aad8e3369.jpg
# Image downloaded: pikwizard_images\55d4da148002142077abea99fdf21919.jpg
# Image downloaded: pikwizard_images\240_F_263313495_9ZowdrLnIb0dQVcaW05lWOVMr1MbMpWL.jpg
# Image downloaded: pikwizard_images\73ced4016badfd32a14c00c80757af27.jpg
# Image downloaded: pikwizard_images\a240d53c9f628fd48a51a747f13e9a5f.jpg
# Image downloaded: pikwizard_images\44321771d124800200d5d9685e3bdfaa.jpg
# Image downloaded: pikwizard_images\77935fb61a8b09739384abe7cc7bb967.jpg
# Image downloaded: pikwizard_images\e06dca86597f51f6d7605f3dd2aef113.jpg
# Image downloaded: pikwizard_images\0d069b258166be65e9a3270eb4588744.jpg
# Image downloaded: pikwizard_images\240_F_114818206_35sGIQWIMvK5vWNWfXDtZ3Uhav0nxIGr.jpg
# Image downloaded: pikwizard_images\bc4cb06387abe33713a3b8a46725f4c8.jpg
# Image downloaded: pikwizard_images\f125c1b421537bfca0a48cc45e9ed774.jpg
# Image downloaded: pikwizard_images\5e67ffd5806cac7b8d996e773e0dcaf8.jpg
# Image downloaded: pikwizard_images\0e6fc3962c32d2afec08381d84b19038.jpg

# %%
#download images and extract metadata
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from PIL import Image
import csv

# Function to download images from URLs
def download_image(image_url, output_dir, title):
    try:
        response = requests.get(image_url)
        if response.status_code == 200:
            image_content = response.content
            image_name = os.path.basename(image_url)
            image_path = os.path.join(output_dir, image_name)
            with open(image_path, 'wb') as f:
                f.write(image_content)
            print(f"Image downloaded: {image_path}")
            return image_path
        else:
            print(f"Failed to download image from: {image_url}")
    except Exception as e:
        print(f"Error downloading image: {e}")

# Function to extract and download images
def extract_and_download_images(url, output_dir):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            img_elements = soup.find_all('img')
            image_metadata = []
            for img_element in img_elements:
                img_url = img_element.get('src')
                if img_url and img_url.endswith('.jpg'):
                    img_url = urljoin(url, img_url)
                    title = img_element.get('alt', '')
                    image_path = download_image(img_url, output_dir, title)
                    if image_path:
                        image_info = get_image_metadata(image_path)
                        image_metadata.append({"Title": title, "URL": img_url, "Info": image_info})
            return image_metadata
    except Exception as e:
        print(f"An error occurred: {e}")

# Function to get image metadata
def get_image_metadata(image_path):
    try:
        with Image.open(image_path) as img:
            info = {
                "format": img.format,
                "mode": img.mode,
                "size": img.size,
                # Add more metadata fields as needed
            }
            return info
    except Exception as e:
        print(f"Error getting image metadata: {e}")
        return {}

# Output directory for downloaded images
output_directory = "pikwizard_images"
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# URL of the Pikwizard website
url = "https://pikwizard.com/most-popular/burst-photo/"

# Extract and download images
image_metadata = extract_and_download_images(url, output_directory)

# Write metadata to a CSV file
csv_file_path = "image_metadata.csv"
csv_header = ["Title", "URL", "Info", "File"]
with open(csv_file_path, mode='w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_header)
    writer.writeheader()
    for metadata in image_metadata:
        metadata["File"] = os.path.basename(metadata["Info"].get("filename", ""))
        if "filename" in metadata["Info"]:
            del metadata["Info"]["filename"]
        writer.writerow(metadata)

print("Metadata saved to:", csv_file_path)
# Out:
# Image downloaded: pikwizard_images\584a20bfaa6a32622b04fe4c59b4d666.jpg
# Image downloaded: pikwizard_images\17b2c3b59725e6e154ecc55fcf1fe111.jpg
# Image downloaded: pikwizard_images\240_F_711360308_EFhrUk5JOmSbYlc8lcIJs0m1rNs8vXnm.jpg
# Image downloaded: pikwizard_images\2773e4c1c81230ae1596f6382a628ffa.jpg
# Image downloaded: pikwizard_images\240_F_668149291_sCSC65dvkW0ZRDF34grzSdtuFCIusMxS.jpg
# Image downloaded: pikwizard_images\a7a5447624f582c55cb7ee04b4ede69d.jpg
# Image downloaded: pikwizard_images\458b7201d968b5de982cb3011cc663bc.jpg
# Image downloaded: pikwizard_images\240_F_688489481_PGjxqDQwbAC2Ae2UJimQzUOCg6i11hQ5.jpg
# Image downloaded: pikwizard_images\b8a7978e52f15b875a08a95b460222cc.jpg
# Image downloaded: pikwizard_images\1fbd62e64b8416f0ffbe0428c31b02bb.jpg
# Image downloaded: pikwizard_images\240_F_637257056_Gx6R0XRaSyuwNsx2SV5ZgTv8yY2FakgR.jpg
# Image downloaded: pikwizard_images\342c0f8f385ed3fa72ecdf39a1da04e3.jpg
# Image downloaded: pikwizard_images\2bdfc39b0a83d9a7c82a5524f7eb430f.jpg
# Image downloaded: pikwizard_images\56a0405fbd5513e66cb95522af56eaa2.jpg
# Image downloaded: pikwizard_images\de0c6ff22b68312241a1bfb442f1a52d.jpg
# Image downloaded: pikwizard_images\240_F_676343188_wPixVs3oUqJprHusjZV0b1aGYt7LZPGT.jpg
# Image downloaded: pikwizard_images\240_F_369207587_L1OrrCW5LFBwEcPwzCsBsDjxkdbhCb7N.jpg
# Image downloaded: pikwizard_images\4c3941e1e616c9b3d1f6688591a9466e.jpg
# Image downloaded: pikwizard_images\240_F_225130590_L3eDiB2ljlDAhn9PkRkhuHM865J4LwOW.jpg
# Image downloaded: pikwizard_images\ffa4af0d8a44cd586fccda076ed02ffa.jpg
# Image downloaded: pikwizard_images\384dd194a9d0eaf0e1fa76387f4bd576.jpg
# Image downloaded: pikwizard_images\240_F_497593949_EsZRDQUvXNQbtzMXjEvOkElU5DiGuX0M.jpg
# Image downloaded: pikwizard_images\357c8f8a6358acea5ef8c88b42d2b722.jpg
# Image downloaded: pikwizard_images\01be1047947bcf6f4b0bc43e3e89273b.jpg
# Image downloaded: pikwizard_images\631dbf192743c9fa81cdc273a4320b83.jpg
# Image downloaded: pikwizard_images\f07c45c48b54347047872af32c4a9ff0.jpg
# Image downloaded: pikwizard_images\240_F_728509050_H79RmZhuXzdZBokLllnbtvzKVBhXo4QW.jpg
# Image downloaded: pikwizard_images\bb1b42004edd19bdb307c739e39ee41c.jpg
# Image downloaded: pikwizard_images\240_F_678475892_EhOVt9C0WPYzqk2L1zCQAlxDj1DLMQbh.jpg
# Metadata saved to: image_metadata.csv
