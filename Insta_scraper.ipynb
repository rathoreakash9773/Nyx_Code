# %%
pip install instaloader
# Out:
# Requirement already satisfied: instaloader in c:\users\akash rathore\anaconda3\lib\site-packages (4.10.3)
# Requirement already satisfied: requests>=2.4 in c:\users\akash rathore\anaconda3\lib\site-packages (from instaloader) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\akash rathore\anaconda3\lib\site-packages (from requests>=2.4->instaloader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\akash rathore\anaconda3\lib\site-packages (from requests>=2.4->instaloader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\akash rathore\anaconda3\lib\site-packages (from requests>=2.4->instaloader) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\akash rathore\anaconda3\lib\site-packages (from requests>=2.4->instaloader) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import instaloader
import os
import pandas as pd
from instaloader.exceptions import ConnectionException

def extract_metadata(username, output_directory, max_posts=5127):
    # Create an instance of Instaloader class
    loader = instaloader.Instaloader()

    try:
        # Retrieve the profile of the provided username
        profile = instaloader.Profile.from_username(loader.context, username)

        # Create a list to store metadata
        metadata_list = []

        # Iterate over the posts of the profile
        for index, post in enumerate(profile.get_posts()):
            # Break the loop if max_posts have been processed
            if index >= max_posts:
                break

            try:
                # Download the media (images and videos) associated with the post
                loader.download_post(post, target=output_directory)

                # Extract metadata
                metadata = {
                    "Post URL": post.url,
                    "Caption": post.caption,
                    "Likes": post.likes,
                    "Comments": post.comments,
                    "Timestamp": post.date_utc
                }
                metadata_list.append(metadata)
            except ConnectionException as e:
                # Handle ConnectionException (HTTP 400 error) gracefully
                print(f"Error downloading post {post.url}: {e}")
                continue  # Skip to the next post

        # Convert metadata list to DataFrame
        metadata_df = pd.DataFrame(metadata_list)

        # Save metadata to CSV file
        metadata_csv_path = os.path.join(output_directory, f"{profile.username}_Final.csv")
        metadata_df.to_csv(metadata_csv_path, index=False)

        print("Metadata extraction completed. CSV file saved at:", metadata_csv_path)
    
    except instaloader.exceptions.ProfileNotExistsException:
        print("Error: Profile does not exist.")

if __name__ == "__main__":
    # Instagram username
    username = "things2doindelhi"  # Instagram_username
    # Output directory
    output_directory = r"D:\Python\NYX\Insta_folders\Delhi"

    extract_metadata(username, output_directory)
# Out:
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-20_15-02-13_UTC.jpg [#newlyopened   Sunny Leone’s …] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-20_15-02-13_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-07_14-22-24_UTC.jpg [#ContestAlert Spice up your l…] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-07_14-22-24_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-17_14-43-03_UTC.jpg [You heard it right, Tulip’s i…] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-17_14-43-03_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-22_16-34-11_UTC.jpg [Saraj Aajeevika Mela 2024 is …] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-22_16-34-11_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-21_15-42-58_UTC.jpg [#things2dofirst   Three newly…] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-21_15-42-58_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-19_14-20-59_UTC.jpg [Here’s your sign to plan perf…] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-19_14-20-59_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-18_15-54-59_UTC.jpg [Tell us your favourite spot t…] json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-16_13-42-52_UTC.jpg [Looking for the best brewery …] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-16_13-42-52_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-15_15-30-06_UTC.jpg [What comes to your mind when …] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-15_15-30-06_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-14_08-52-51_UTC.jpg [To our Single people gang let…] json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_13-17-35_UTC.jpg [Who doesn’t adore flowers & e…] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_13-17-35_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_09-33-05_UTC_1.jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_09-33-05_UTC_2.jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_09-33-05_UTC_3.jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_09-33-05_UTC_4.jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_09-33-05_UTC_5.jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_09-33-05_UTC_6.jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_09-33-05_UTC_7.jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_09-33-05_UTC_8.jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_09-33-05_UTC_9.jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-13_09-33-05_UTC_10.jpg [Delhi February can’t get bett…] json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-12_15-52-18_UTC.jpg [Tag your @babe & ask her out …] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-12_15-52-18_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-11_15-20-31_UTC.jpg [8 cafe’s which are 10/10 for …] D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02-11_15-20-31_UTC.mp4 json
# D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2024-02
jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2021-09-16_13-02-09_UTC_5.jpg D：﹨Python﹨NYX﹨Insta_folders﹨Delhi\2021-09-16_13-02-09_UTC_6.jpg [This cutesy little cafe in Gu…] json
# JSON Query to graphql/query: HTTP error code 401. [retrying; skip with ^C]
# JSON Query to graphql/query: HTTP error code 401. [retrying; skip with ^C]
# ---------------------------------------------------------------------------
# ConnectionException                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\instaloader\instaloadercontext.py:409, in InstaloaderContext.get_json(self, path, params, host, session, _attempt, response_headers)
#     408 if resp.status_code != 200:
# --> 409     raise ConnectionException("HTTP error code {}.".format(resp.status_code))
#     410 else:
#
# ConnectionException: HTTP error code 401.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionException                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\instaloader\instaloadercontext.py:409, in InstaloaderContext.get_json(self, path, params, host, session, _attempt, response_headers)
#     408 if resp.status_code != 200:
# --> 409     raise ConnectionException("HTTP error code {}.".format(resp.status_code))
#     410 else:
#
# ConnectionException: HTTP error code 401.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionException                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\instaloader\instaloadercontext.py:409, in InstaloaderContext.get_json(self, path, params, host, session, _attempt, response_headers)
#     408 if resp.status_code != 200:
# --> 409     raise ConnectionException("HTTP error code {}.".format(resp.status_code))
#     410 else:
#
# ConnectionException: HTTP error code 401.
#
# The above exception was the direct cause of the following exception:
#
# ConnectionException                       Traceback (most recent call last)
# Cell In[1], line 59
#      56 # Output directory
#      57 output_directory = r"D:\Python\NYX\Insta_folders\Delhi"
# ---> 59 extract_metadata(username, output_directory)
#
# Cell In[1], line 18, in extract_metadata(username, output_directory, max_posts)
#      15 metadata_list = []
#      17 # Iterate over the posts of the profile
# ---> 18 for index, post in enumerate(profile.get_posts()):
#      19     # Break the loop if max_posts have been processed
#      20     if index >= max_posts:
#      21         break
#
# File ~\anaconda3\Lib\site-packages\instaloader\nodeiterator.py:141, in NodeIterator.__next__(self)
#     139     return item
#     140 if self._data.get('page_info', {}).get('has_next_page'):
# --> 141     query_response = self._query(self._data['page_info']['end_cursor'])
#     142     if self._data['edges'] != query_response['edges'] and len(query_response['edges']) > 0:
#     143         page_index, data = self._page_index, self._data
#
# File ~\anaconda3\Lib\site-packages\instaloader\nodeiterator.py:103, in NodeIterator._query(self, after)
#     100     pagination_variables['after'] = after
#     101 try:
#     102     data = self._edge_extractor(
# --> 103         self._context.graphql_query(
#     104             self._query_hash, {**self._query_variables, **pagination_variables}, self._query_referer
#     105         )
#     106     )
#     107     self._best_before = datetime.now() + NodeIterator._shelf_life
#     108     return data
#
# File ~\anaconda3\Lib\site-packages\instaloader\instaloadercontext.py:470, in InstaloaderContext.graphql_query(self, query_hash, variables, referer, rhx_gis)
#     467         x_instagram_gis = hashlib.md5(values.encode()).hexdigest()
#     468         tmpsession.headers['x-instagram-gis'] = x_instagram_gis
# --> 470     resp_json = self.get_json('graphql/query',
#     471                               params={'query_hash': query_hash,
#     472                                       'variables': variables_json},
#     473                               session=tmpsession)
#     474 if 'status' not in resp_json:
#     475     self.error("GraphQL response did not contain a \"status\" field.")
#
# File ~\anaconda3\Lib\site-packages\instaloader\instaloadercontext.py:435, in InstaloaderContext.get_json(self, path, params, host, session, _attempt, response_headers)
#     433         if is_other_query:
#     434             self._rate_controller.handle_429('other')
# --> 435     return self.get_json(path=path, params=params, host=host, session=sess, _attempt=_attempt + 1,
#     436                          response_headers=response_headers)
#     437 except KeyboardInterrupt:
#     438     self.error("[skipped by user]", repeat_at_end=False)
#
# File ~\anaconda3\Lib\site-packages\instaloader\instaloadercontext.py:435, in InstaloaderContext.get_json(self, path, params, host, session, _attempt, response_headers)
#     433         if is_other_query:
#     434             self._rate_controller.handle_429('other')
# --> 435     return self.get_json(path=path, params=params, host=host, session=sess, _attempt=_attempt + 1,
#     436                          response_headers=response_headers)
#     437 except KeyboardInterrupt:
#     438     self.error("[skipped by user]", repeat_at_end=False)
#
# File ~\anaconda3\Lib\site-packages\instaloader\instaloadercontext.py:425, in InstaloaderContext.get_json(self, path, params, host, session, _attempt, response_headers)
#     423         raise QueryReturnedNotFoundException(error_string) from err
#     424     else:
# --> 425         raise ConnectionException(error_string) from err
#     426 self.error(error_string + " [retrying; skip with ^C]", repeat_at_end=False)
#     427 try:
#
# ConnectionException: JSON Query to graphql/query: HTTP error code 401.

# %%
import instaloader
import os
import pandas as pd

def extract_metadata(username, output_directory):
    # Create an instance of Instaloader class
    loader = instaloader.Instaloader()

    try:
        # Retrieve the profile of the provided username
        profile = instaloader.Profile.from_username(loader.context, username)

        # Create a list to store metadata
        metadata_list = []

        # Iterate over the posts of the profile
        for post in profile.get_posts():
            # Download the media (images and videos) associated with the post
            loader.download_post(post, target=output_directory)

            # Extract metadata
            metadata = {
                "Post URL": post.url,
                "Caption": post.caption,
                "Likes": post.likes,
                "Comments": post.comments,
                "Timestamp": post.date_utc
            }
            metadata_list.append(metadata)
        
        # Convert metadata list to DataFrame
        metadata_df = pd.DataFrame(metadata_list)

        # Save metadata to CSV file
        metadata_csv_path = os.path.join(output_directory, f"{profile.username}_Final.csv")
        metadata_df.to_csv(metadata_csv_path, index=False)

        print("Metadata extraction completed. CSV file saved at:", metadata_csv_path)
    
    except instaloader.exceptions.ProfileNotExistsException:
        print("Error: Profile does not exist.")

if __name__ == "__main__":
    # Instagram username
    username = "explore.indiatourism "      #instagram_username
    # Output directory
    output_directory = r"D:\Python\NYX\Insta_folders\india10"           

    extract_metadata(username, output_directory)
# Out:
# HTTP redirect from https://i.instagram.com/api/v1/users/web_profile_info/?username=explore.indiatourism  to https://i.instagram.com/accounts/login/?next=/api/v1/users/web_profile_info/
# ---------------------------------------------------------------------------
# LoginRequiredException                    Traceback (most recent call last)
# Cell In[2], line 49
#      46 # Output directory
#      47 output_directory = r"D:\Python\NYX\Insta_folders\india10"
# ---> 49 extract_metadata(username, output_directory)
#
# Cell In[2], line 11, in extract_metadata(username, output_directory)
#       7 loader = instaloader.Instaloader()
#       9 try:
#      10     # Retrieve the profile of the provided username
# ---> 11     profile = instaloader.Profile.from_username(loader.context, username)
#      13     # Create a list to store metadata
#      14     metadata_list = []
#
# File ~\anaconda3\Lib\site-packages\instaloader\structures.py:810, in Profile.from_username(cls, context, username)
#     808 # pylint:disable=protected-access
#     809 profile = cls(context, {'username': username.lower()})
# --> 810 profile._obtain_metadata()  # to raise ProfileNotExistsException now in case username is invalid
#     811 return profile
#
# File ~\anaconda3\Lib\site-packages\instaloader\structures.py:879, in Profile._obtain_metadata(self)
#     877 try:
#     878     if not self._has_full_metadata:
# --> 879         metadata = self._context.get_iphone_json(f'api/v1/users/web_profile_info/?username={self.username}',
#     880                                                  params={})
#     881         if metadata['data']['user'] is None:
#     882             raise ProfileNotExistsException('Profile {} does not exist.'.format(self.username))
#
# File ~\anaconda3\Lib\site-packages\instaloader\instaloadercontext.py:567, in InstaloaderContext.get_iphone_json(self, path, params)
#     564     tempsession.cookies.clear()
#     566 response_headers = dict()    # type: Dict[str, Any]
# --> 567 response = self.get_json(path, params, 'i.instagram.com', tempsession, response_headers=response_headers)
#     569 # Extract the ig-set-* headers and use them in the next request
#     570 for key, value in response_headers.items():
#
# File ~\anaconda3\Lib\site-packages\instaloader\instaloadercontext.py:391, in InstaloaderContext.get_json(self, path, params, host, session, _attempt, response_headers)
#     388 if (redirect_url.startswith('https://www.instagram.com/accounts/login') or
#     389     redirect_url.startswith('https://i.instagram.com/accounts/login')):
#     390     if not self.is_logged_in:
# --> 391         raise LoginRequiredException("Redirected to login page. Use --login.")
#     392     raise AbortDownloadException("Redirected to login page. You've been logged out, please wait " +
#     393                                  "some time, recreate the session and try again")
#     394 if redirect_url.startswith('https://{}/'.format(host)):
#
# LoginRequiredException: Redirected to login page. Use --login.

# %%
import os
import shutil

def filter_and_copy_files(input_directory, output_directory):
    # Create the output directory if it does not exist
    os.makedirs(output_directory, exist_ok=True)

    # Create subdirectories for Images and Videos
    images_directory = os.path.join(output_directory, 'Images')
    videos_directory = os.path.join(output_directory, 'Videos')
    os.makedirs(images_directory, exist_ok=True)
    os.makedirs(videos_directory, exist_ok=True)

    # Iterate through all files in the input directory
    for filename in os.listdir(input_directory):
        # Check if the file is a JPG or MP4 file
        if filename.endswith('.jpg'):
            # Construct the full path of the file
            source_file = os.path.join(input_directory, filename)
            # Copy the file to the Images subdirectory
            shutil.copy(source_file, os.path.join(images_directory, filename))
        elif filename.endswith('.mp4'):
            # Construct the full path of the file
            source_file = os.path.join(input_directory, filename)
            # Copy the file to the Videos subdirectory
            shutil.copy(source_file, os.path.join(videos_directory, filename))

    print("Filtered files copied to:", output_directory)

if __name__ == "__main__":
    # Input directory containing downloaded files
    input_directory = r"D：﹨Python﹨NYX﹨Insta_folders﹨Delhi"
    # Output directory for filtered files
    output_directory = r"D:\Python\NYX\Insta_folders\Delhi"

    filter_and_copy_files(input_directory, output_directory)
# Out:
# Filtered files copied to: D:\Python\NYX\Insta_folders\india10

# %%
import os
import csv
from moviepy.editor import VideoFileClip

def get_video_duration(file_path):
    try:
        clip = VideoFileClip(file_path)
        duration = clip.duration
        clip.close()
        return duration
    except Exception as e:
        print(f"Error extracting duration for {file_path}: {e}")
        return None

def generate_csv(folder_path, csv_filename):
    # Create or open the CSV file for writing
    with open(csv_filename, 'w', newline='') as csv_file:
        # Create a CSV writer object
        csv_writer = csv.writer(csv_file)

        # Write header to the CSV file
        csv_writer.writerow(['File Name', 'File Type', 'Duration (s)'])

        # Traverse through the folder and its subfolders
        for root, dirs, files in os.walk(folder_path):
            for file_name in files:
                file_path = os.path.join(root, file_name)

                # Get the file extension
                file_type = file_name.split('.')[-1]

                # Get duration for videos, None for non-video files
                if file_type.lower() in ['mp4', 'avi', 'mkv', 'mov']:
                    duration = get_video_duration(file_path)
                else:
                    duration = None

                # Write information to the CSV file
                csv_writer.writerow([file_name, file_type, duration])

    print(f"CSV file '{csv_filename}' generated successfully.")

# Provide the folder path and desired CSV filename
folder_path = r'D:\Python\NYX\Insta_folders\Delhi1'
csv_filename = 'Delhi1_metadata.csv'

# Call the function to generate the CSV file
generate_csv(folder_path, csv_filename)
# Out:
# CSV file 'Delhi1_metadata.csv' generated successfully.
